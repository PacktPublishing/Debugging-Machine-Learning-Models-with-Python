# %% [markdown]
# # Chapter 8
# ## Section: Pytest fixtures (extra features)

# %%
# !pip install -U pytest
# !pip install ipytest

# %%
# contents of test_append.py
import pytest

# Arrange
@pytest.fixture
def first_entry():
    return "a"

# Arrange
@pytest.fixture
def order():
    return []

# %%
import pytest
import ipytest
ipytest.autoconfig()

# %%
# %%ipytest -qq
# # Act
# @pytest.fixture
# def append_first(order, first_entry):
#     return order.append(first_entry)
#
#
# def test_string_only(append_first, order, first_entry):
#     # Assert
#     assert order == [first_entry]
# Out:
# .                                                                                            [100%]

# %%
# In Jupyter and Colab notebook
ipytest.run()
# Out:
# .                                                                                            [100%]
# 1 passed in 0.03s
# <ExitCode.OK: 0>
